# %% [markdown]
# <a href="https://colab.research.google.com/github/sinku29/Data-Science-Assignment/blob/main/21b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
wc_at = pd.read_csv('/content/wc-at.csv')

# %%
plt.hist(wc_at["AT"])
# Out:
# (array([14., 18., 16., 13., 17., 14.,  4.,  6.,  3.,  4.]),
#  array([ 11.44 ,  35.596,  59.752,  83.908, 108.064, 132.22 , 156.376,
#         180.532, 204.688, 228.844, 253.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(wc_at["AT"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e2d23806f80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e2d23805540>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e2d238076d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e2d238049d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e2d238061a0>],
#  'means': []}

# %%
plt.hist(wc_at["Waist"])
# Out:
# (array([ 2.,  9., 19., 17., 11.,  9., 13., 21.,  5.,  3.]),
#  array([ 63.5 ,  69.25,  75.  ,  80.75,  86.5 ,  92.25,  98.  , 103.75,
#         109.5 , 115.25, 121.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(wc_at["Waist"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e2d2374bf40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e2d23748280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e2d2374a7d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e2d238999f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e2d23898fa0>],
#  'means': []}
